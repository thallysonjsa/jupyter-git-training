# %%
import pandas as pd

# %%
df = pd.read_csv('../data/winequality-red.csv', sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
melhores = df[df['quality'].isin([8, 9, 10])]

# %%
melhores.reset_index(drop=True)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.9              0.35         0.46             3.6      0.078
# 1            10.3              0.32         0.45             6.4      0.073
# 2             5.6              0.85         0.05             1.4      0.045
# 3            12.6              0.31         0.72             2.2      0.072
# 4            11.3              0.62         0.67             5.2      0.086
# 5             9.4              0.30         0.56             2.8      0.080
# 6            10.7              0.35         0.53             2.6      0.070
# 7            10.7              0.35         0.53             2.6      0.070
# 8             5.0              0.42         0.24             2.0      0.060
# 9             7.8              0.57         0.09             2.3      0.065
# 10            9.1              0.40         0.50             1.8      0.071
# ...

# %%
melhores.iloc[:5]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267            7.9              0.35         0.46             3.6      0.078
# 278           10.3              0.32         0.45             6.4      0.073
# 390            5.6              0.85         0.05             1.4      0.045
# 440           12.6              0.31         0.72             2.2      0.072
# 455           11.3              0.62         0.67             5.2      0.086
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 267                 15.0                  37.0   0.9973  3.35       0.86
# 278                  5.0                  13.0   0.9976  3.23       0.82
# 390                 12.0                  88.0   0.9924  3.56       0.82
# 440                  6.0                  29.0   0.9987  2.88       0.82
# 455                  6.0                  19.0   0.9988  3.22       0.69
#
#      alcohol  quality
# 267     12.8        8
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20,10))
melhores.plot()
